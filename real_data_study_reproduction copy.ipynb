# %% [markdown]
# # Regime-PCMCI: Detecting causal regimes from multivariate time series
#
# Main reference: Elena Saggioro, Jana de Wiljes, Marlene Kretschmer, Jakob Runge; Reconstructing regime-dependent causal relationships from observational time series. Chaos 1 November 2020; 30 (11): 113115. https://doi.org/10.1063/5.0020538
#
# The following Nature Review Earth and Environment paper provides an overview of causal inference for time series in general: https://github.com/jakobrunge/tigramite/blob/master/tutorials/Runge_Causal_Inference_for_Time_Series_NREE.pdf

# %%
# Imports
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline     
## use `%matplotlib notebook` for interactive figures
# plt.style.use('ggplot')
import sklearn
from sklearn.linear_model import LinearRegression


import tigramite
from tigramite import data_processing as pp
from tigramite.toymodels import structural_causal_processes as toys
from tigramite import plotting as tp
from tigramite.pcmci import PCMCI
from tigramite.rpcmci import RPCMCI


from tigramite.independence_tests.parcorr import ParCorr
from tigramite.independence_tests.gpdc import GPDC
from tigramite.independence_tests.cmiknn import CMIknn
from tigramite.independence_tests.cmisymb import CMIsymb

# %% [markdown]
# ![figures/causal_stationarity_2.png](attachment:causal_stationarity_2.png)

# %% [markdown]
# Below we generate data in which the underlying causal structure alternates between two regimes that are referred to as winter half year and summer half year. In particular, the two regimes differ in that one causal effect is of opposite sign in the two regimes.
#
# Importantly, Regime-PCMCI does not require a periodic structure of regimes, they can be arbitrarily distributed across time. However, there are assumptions on the number of regimes and their persistency. For the assumptions of R-PCMCI, see the paper above.

# %%
np.random.seed(43)
T = 500
var_names = [r'$X^1$', r'$X^2$', r'$X^3$']
data = np.random.randn(T, 3)
data_mask = np.zeros(data.shape)
for t in range(1, T):
    if (t % 365) < 3*30 or (t % 365) > 8*30: 
        # Winter half year
        data[t, 0] +=  0.4*data[t-1, 0]
        data[t, 1] +=  0.3*data[t-1, 1] + 0.7*data[t-1, 0]
        data[t, 2] +=  0.3*data[t-1, 2] + 0.7*data[t-1, 0]
    else:
        # Summer half year
        data_mask[[t, t-1]] = True
        data[t, 0] +=  0.4*data[t-1, 0]
        data[t, 1] +=  0.3*data[t-1, 1]  - 0.7*data[t-1, 0]
        data[t, 2] +=  0.3*data[t-1, 2] 

T, N = data.shape
# print data_mask[:100, 0]
datatime = np.arange(T)
dataframe_plotting = pp.DataFrame(data, mask=data_mask)
tp.plot_timeseries(dataframe_plotting, figsize=(8,3), grey_masked_samples='data'); plt.show()

# %% [markdown]
# ## Learning graphs if causal regimes are known
#
# Let's first reconstruct the causal graphs belonging to the two regimes by explicitly including knowledge about the regimes via *masking*. See the tutorial on masking in the folder dataset_challenges.

# %%
# First mask out the summer
pcmci = PCMCI(dataframe=dataframe_plotting, 
              cond_ind_test=ParCorr(mask_type='y'))
results = pcmci.run_pcmci(tau_min=1, tau_max=2, pc_alpha=0.2, alpha_level=0.01)
tp.plot_graph(val_matrix=results['val_matrix'],
              graph=results['graph'], var_names=var_names,
              node_aspect=0.5, node_size=0.5
)
plt.show()

# %%
# Then mask out the winter
dataframe_plotting.mask[0] = dataframe_plotting.mask[0] == False
pcmci = PCMCI(dataframe=dataframe_plotting, 
              cond_ind_test=ParCorr(mask_type='y'))
results = pcmci.run_pcmci(tau_min=1, tau_max=2, pc_alpha=0.2, alpha_level=0.01)
tp.plot_graph(val_matrix=results['val_matrix'],
              graph=results['graph'], var_names=var_names,
              node_aspect=0.5, node_size=0.5
)
plt.show()

# %% [markdown]
# ## Ignore regimes and learn graph over all data
#
# Just as an illustration.

# %%
pcmci = PCMCI(dataframe=pp.DataFrame(data), 
              cond_ind_test=ParCorr())
results = pcmci.run_pcmci(tau_min=1, tau_max=2, pc_alpha=0.2, alpha_level=0.01)
tp.plot_graph(val_matrix=results['val_matrix'],
              graph=results['graph'], var_names=var_names,
              node_aspect=0.5, node_size=0.5
)
plt.show()

# %% [markdown]
# ## Learn regimes and corresponding causal graphs
#
# Now run RPCMCI to automatically detect the causal regimes without assuming them with masking.

# %%
# Dataframe init. Note that for R-PCMCI no data mask can be used. 
# The mask will internally be overwritten to learn regimes
dataframe = pp.DataFrame(data)

# Init RPCMCI with the dataframe, a conditional independence test for use in PCMCI, 
# and a prediction_model which is used to predict each variable given its learned parents. This prediction 
# is then used inside the regime learning optimization step.
rpcmci = RPCMCI(dataframe=dataframe, 
                cond_ind_test=ParCorr(),
                prediction_model=LinearRegression(),
                verbosity=1)

# RPCMCI parameters, see paper
num_regimes = 2
max_transitions = 4
switch_thres = 0.05
num_iterations = 20
max_anneal = 10
tau_min = 1
tau_max = 1
pc_alpha = 0.2
alpha_level = 0.01
n_jobs = -1     # uses joblib for parallelization, here all available cpus are used

# Run RPCMCI
results = rpcmci.run_rpcmci(
    num_regimes=num_regimes, max_transitions=max_transitions, 
    switch_thres=switch_thres, 
    num_iterations=num_iterations, max_anneal=max_anneal, 

    tau_min=tau_min, tau_max=tau_max,
    pc_alpha=pc_alpha, alpha_level=alpha_level, 
    n_jobs=n_jobs
    )

if results is None:
    print("All annealings resulted in errors. Increase annealing and tune other parameters!")
else:
    print("Done!")
# Out:
# ################# Annealing iteration a = 0 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
#
# ################# Annealing iteration a = 1 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# ################# Annealing iteration a = 2 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
#
# ################# Annealing iteration a = 3 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 503.5399195755775
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 490.9369752339443
#
# ###### Optimization step q = 1
# ################ Regime k = 0
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 506.8945776858816
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 490.94465076110276
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 29.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 48.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 38.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 36.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 0.0
# Two consecutive gammas are equal: (local) minimum reached. Go to next annealing.
#
#
# ################# Annealing iteration a = 4 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 0.0
# Two consecutive gammas are equal: (local) minimum reached. Go to next annealing.
#
#
# ################# Annealing iteration a = 5 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 0.0
# Two consecutive gammas are equal: (local) minimum reached. Go to next annealing.
#
#
# ################# Annealing iteration a = 6 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 0.0
# Two consecutive gammas are equal: (local) minimum reached. Go to next annealing.
#
#
# ################# Annealing iteration a = 7 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 498.27206003227985
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 511.59244891703486
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 497.3406581357441
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 488.8982226990487
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 40.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 38.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 172.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 36.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 0.0
# Two consecutive gammas are equal: (local) minimum reached. Go to next annealing.
#
#
# ################# Annealing iteration a = 8 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 0.0
# Two consecutive gammas are equal: (local) minimum reached. Go to next annealing.
#
#
# ################# Annealing iteration a = 9 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 253.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 0.0
# Two consecutive gammas are equal: (local) minimum reached. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 517.2240554833973
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 494.923101079663
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 75.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 36.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 12.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 248.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 0.0
# Two consecutive gammas are equal: (local) minimum reached. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 350.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 0.0
# Two consecutive gammas are equal: (local) minimum reached. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 31.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 7.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 0.0
# Two consecutive gammas are equal: (local) minimum reached. Go to next annealing.
#
# Done!

# %%
regimes = results['regimes'].argmax(axis=0)
n_regimes = len(results['causal_results'])

# Create nice Mosaic plot
mosaic = [['data %s' %j for i in range(n_regimes)] for j in range(N+1)]
for n in range(N):
    mosaic.append(['graph %s' %i for i in range(n_regimes)])

fig, axs = plt.subplot_mosaic(mosaic = mosaic, figsize=(20, 10))

for j in range(N):
    ax = axs['data %s' %j]
    ax.axhline(0., color='grey')
    ax.plot(datatime, data[:,j])
    for loc, spine in ax.spines.items():
        if loc != 'left':
            spine.set_color("none")
    
    ax.xaxis.set_ticks([])   
    ax.set_xlim(0., T)
    ax.set_ylabel(var_names[j])
    
# Regime variable
ax = axs['data %s' %N]
ax.plot(datatime, regimes.astype('int'), lw=3, color='black')
for loc, spine in ax.spines.items():
    if loc != 'left':
        spine.set_color("none")
ax.xaxis.set_ticks([]) 
ax.yaxis.set_ticks(range(n_regimes))   
ax.set_xlim(0., T)
ax.set_ylabel("Regime")
    
# Causal graphs for each regime
for w in range(n_regimes):
    if w == 0: show_colorbar=True
    else: show_colorbar = False
    tp.plot_graph(graph=results['causal_results'][w]['graph'], 
                  val_matrix=results['causal_results'][w]['val_matrix'], 
                  show_colorbar=show_colorbar,
                  var_names=var_names,
                  fig_ax=(fig, axs['graph %s' %w]))
    axs['graph %s' %w].set_title("Regime %d" %w, pad=-4)

fig.subplots_adjust(hspace=0.6)
plt.show()

# %% [markdown]
# The regimes are reconstructed well here. For any real data application, we suggest to construct some toy data with similar properties and then explore which parameters work best for RPCMCI.
#
# We also would like to note that, at present, we have no theoretical results on which types of regime changes are identifiable with this method. However, we demonstrate in numerical experiments, that it works for changes in the graph structure, or the magnitude and sign of links.

# %% [markdown]
# # Reproducting ENSO and AIR(All-India Rainfall) experiment

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import sys

# import sklearn
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import StandardScaler

# import tigramite
# import tigramite.data_processing as pp
# import tigramite.plotting as tp

# from tigramite.models import LinearMediation, Models
# from tigramite.causal_effects import CausalEffects

# # Function to remove seasonal mean and divide by seasonal standard deviation
# def anomalize(dataseries, divide_by_std=True, reference_bounds = None, cycle_length=12, return_cycle=False):
#     if reference_bounds is None:
#         reference_bounds = (0, len(dataseries))

#     anomaly = np.copy(dataseries)
#     for t in range(cycle_length):
#         if return_cycle:
#             anomaly[t::cycle_length] = dataseries[t+reference_bounds[0]:reference_bounds[1]:cycle_length].mean(axis=0)
#         else:
#             anomaly[t::cycle_length] -= dataseries[t+reference_bounds[0]:reference_bounds[1]:cycle_length].mean(axis=0)
#             if divide_by_std:
#                 anomaly[t::cycle_length] /= dataseries[t+reference_bounds[0]:reference_bounds[1]:cycle_length].std(axis=0)
#     return anomaly

# %% [markdown]
# ## Loading the data

# %% [markdown]
# ### Loading ENSO

# %%
nino34 = np.loadtxt("nino3.4_2025.dat.txt")

# %% [markdown]
# ### Loading AIR

# %%
AIR = np.loadtxt("AIR.dat.txt")

# %%
# now the air data has the columns YEAR, Rain-January, Rain-February, Rain-March, Rain-April, Rain-May, Rain-June, Rain-July, Rain-August, Rain-September, Rain-October, Rain-November, Rain-December
# we reshape it so to have only two columns: TIME and RAIN where each row is the value for eahc month in chronological order
start_year = AIR[0,0]

end_year = AIR[-1,0]


print(f"Start year: {start_year}, End year: {end_year}")

AIR = AIR[:,1:].reshape(-1,1)

# summarize the data
print(AIR.shape)

# add a time column
time = np.arange(start_year, end_year + 1, 1/12)

# add the time column to the data
AIR = np.hstack((time.reshape(-1,1), AIR))
# Out:
# Start year: 1871.0, End year: 2016.0
# (1752, 1)

# %%
AIR
# Out:
# array([[1871.        ,   19.6       ],
#        [1871.08333333,   10.7       ],
#        [1871.16666667,   14.5       ],
#        ...,
#        [2016.75      ,   52.1       ],
#        [2016.83333333,    8.        ],
#        [2016.91666667,    7.        ]])

# %% [markdown]
# ### Pre-processing
# Making the data stationary (don't know yet if necessary)

# %%
# cycle_length = 12
# smooth_width = cycle_length*10
# if smooth_width is not None: 
#     data_here = pp.smooth(data=np.copy(data), smooth_width=smooth_width, kernel='gaussian',
#                     residuals=True)
# else:
#     data_here = np.copy(data)

# data_here = anomalize(data_here, cycle_length=cycle_length)

# %% [markdown]
# ### Join datasets

# %%
# cut the nino34 data to the same time period as the air data
nino34 = nino34[(nino34[:, 0] >= start_year) & (nino34[:, 0] < end_year + 1 )]

# %%
AIR[:,0] = AIR[:,0].round(2)

nino34[:,0] = nino34[:,0].round(2)

# %%
assert nino34.shape[0] == AIR.shape[0], f"Number of months are different: Nino34: {nino34.shape[0]}, AIR: {AIR.shape[0]}"
print (f"{nino34.shape[0]} ,  {AIR.shape[0]}")

# assert the the number of month for the first and the last year are the same for both datasets

nino_first_y_months = nino34[(nino34[:,0] >= start_year) & (nino34[:,0] < start_year + 1)].shape[0]

AIR_first_y_months = AIR[(AIR[:,0] >= start_year) & (AIR[:,0] < start_year + 1)].shape[0]

assert nino_first_y_months == AIR_first_y_months, f"Number of months for the first year are different: Nino34: {nino_first_y_months}, AIR: {AIR_first_y_months}"

nino_last_y_months = nino34[(nino34[:,0] >= end_year) & (nino34[:,0] < end_year+1)].shape[0]

AIR_last_y_months = AIR[(AIR[:,0] >= end_year ) & (AIR[:,0] < end_year+1)].shape[0]

assert nino_last_y_months == AIR_last_y_months, f"Number of months for the last year are different: Nino34: {nino_last_y_months}, AIR: {AIR_last_y_months}"
# Out:
# 1752 ,  1752

# %%
# join datasets
data = np.hstack((AIR, nino34[:,1].reshape(-1,1)))

# %% [markdown]
# ## Applying regime-PCMCI to the climate data

# %%
max_transitions = (end_year - start_year + 1)*2

# %%
max_transitions
# Out:
# 292.0

# %%
# Dataframe init. Note that for R-PCMCI no data mask can be used. 
# The mask will internally be overwritten to learn regimes

datetime = data[:,0]
data = data[:,1:]
dataframe = pp.DataFrame(data)

# Init RPCMCI with the dataframe, a conditional independence test for use in PCMCI, 
# and a prediction_model which is used to predict each variable given its learned parents. This prediction 
# is then used inside the regime learning optimization step.
rpcmci = RPCMCI(dataframe=dataframe, 
                cond_ind_test=ParCorr(),
                prediction_model=LinearRegression(),
                verbosity=1)

# RPCMCI parameters, see paper
num_regimes = 2
max_transitions = max_transitions
switch_thres = 0.5 #It was set to 0.05, but paper says 0.5
num_iterations = 100
max_anneal = 100
tau_min = 1
tau_max = 2
pc_alpha = 0.2
alpha_level = 0.01
n_jobs = -1     # uses joblib for parallelization, here all available cpus are used

# Run RPCMCI
results = rpcmci.run_rpcmci(
    num_regimes=num_regimes, max_transitions=max_transitions, 
    switch_thres=switch_thres, 
    num_iterations=num_iterations, max_anneal=max_anneal, 

    tau_min=tau_min, tau_max=tau_max,
    pc_alpha=pc_alpha, alpha_level=alpha_level, 
    n_jobs=n_jobs
    )

if results is None:
    print("All annealings resulted in errors. Increase annealing and tune other parameters!")
else:
    print("Done!")
# Out:
# ################# Annealing iteration a = 1 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
#
# ################# Annealing iteration a = 0 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
#
# ################# Annealing iteration a = 2 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# ################# Annealing iteration a = 5 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
#
# ################# Annealing iteration a = 6 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
#
# ################# Annealing iteration a = 7 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
#
# ################# Annealing iteration a = 4 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
#
# ################# Annealing iteration a = 3 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
# ################ Regime k = 1
#
# ################# Annealing iteration a = 9 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# ################# Annealing iteration a = 8 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1727.0104094390304
#
# ###### Optimization step q = 1
# ################ Regime k = 0
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1726.7023691291743
#
# ###### Optimization step q = 1
# ################ Regime k = 0
#
# Optimal objective: reached.
#
# Optimal objective: reached.
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1748.3052232869688
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1733.9715267953788
#
# ###### Optimization step q = 1
# ################ Regime k = 0
#
# Optimal objective: reached.
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1724.6998552072487
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1754.3232544239836
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1706.6001997083606
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1722.1448958290196
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1737.2540637889874
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1738.641776362479
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 854.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1635.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1000.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
#
# Optimal objective: reached.
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1097.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 631.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 520.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
#
# Optimal objective: reached.
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 195.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 576.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1533.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 667.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 558.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 590.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 595.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 375.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 429.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 355.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 923.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 754.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 572.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 950.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 269.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 380.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 546.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 386.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 251.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 400.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 243.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 583.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 318.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 247.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 278.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 436.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
#
# Optimal objective: reached.
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 156.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 349.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 276.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
#
# Optimal objective: reached.
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 104.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 184.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 862.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 229.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 256.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 387.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 122.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 88.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 271.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 288.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 176.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 64.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 10 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 509.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 188.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 220.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 50.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# Optimal objective: reached.
#
# ################# Annealing iteration a = 11 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 268.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 52.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 12 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 250.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 207.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1727.350228285421
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 180.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
#
# Optimal objective: reached.
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 337.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 456.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 104.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1742.2286710050982
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 256.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
#
# Optimal objective: reached.
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 150.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 328.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1765.9738914850072
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
# ################ Regime k = 1
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 464.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 209.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 186.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 542.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 54.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 13 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 454.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 538.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1803.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
#
# Optimal objective: reached.
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 276.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 126.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 276.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 132.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1756.0899313536013
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 256.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 270.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 364.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 302.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 193.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 488.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 188.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 138.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 116.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 339.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 166.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 529.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 146.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 271.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 220.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 106.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 168.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 100.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 122.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 126.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 84.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 664.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 90.0
#
# ###### Optimization step q = 12
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 162.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 234.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 82.0
#
# ###### Optimization step q = 12
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 106.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 64.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 14 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 72.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 172.0
#
# ###### Optimization step q = 12
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 47.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 15 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 224.0
#
# ###### Optimization step q = 12
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 42.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 16 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 98.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 28.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 17 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 80.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 384.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1748.6646261415785
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 44.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1716.7555965825056
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 292.0
#
# ###### Optimization step q = 13
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 106.0
#
# ###### Optimization step q = 13
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1704.5568163482662
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 58.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 18 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1738.6903667755787
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 88.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 478.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 594.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 864.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 60.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 19 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 524.0
#
# ###### Optimization step q = 14
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 50.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 20 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 387.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1712.6199801343278
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 725.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 108.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 414.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 182.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 354.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1752.6839064434407
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 649.0
#
# ###### Optimization step q = 15
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1740.2854406907113
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 719.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 993.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 586.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 228.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 251.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 181.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 230.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 777.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 201.0
#
# ###### Optimization step q = 16
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 632.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 563.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 193.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 440.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 397.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 314.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 94.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 159.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 499.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 117.0
#
# ###### Optimization step q = 17
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 450.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 114.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 562.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 274.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 671.0
#
# ###### Optimization step q = 12
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 258.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 88.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 70.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 21 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 307.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 61.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 22 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 354.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 44.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 341.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 276.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 425.0
#
# ###### Optimization step q = 13
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 251.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 66.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 23 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1706.4334943887425
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 198.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1721.3790699420076
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 319.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 34.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 24 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 234.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 102.0
#
# ###### Optimization step q = 14
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 298.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1729.7006827842138
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 240.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 246.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 273.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 577.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 234.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 174.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1714.2688420413592
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 69.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 25 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# ...
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 56.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# ################# Annealing iteration a = 99 ####################
#
#
# ###### Optimization step q = 0
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 548.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 139.0
#
# ###### Optimization step q = 12
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 582.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1706.182691122904
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 234.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 318.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 105.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 246.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 118.0
#
# ###### Optimization step q = 13
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 48.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 1747.8040500134161
#
# ###### Optimization step q = 1
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 266.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 608.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 784.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 176.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 112.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 98.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 108.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 95.0
#
# ###### Optimization step q = 14
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 510.0
#
# ###### Optimization step q = 2
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 90.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 432.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 376.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 146.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 68.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 57.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 66.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 48.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 208.0
#
# ###### Optimization step q = 3
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 369.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 66.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 225.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 110.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 36.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 368.0
#
# ###### Optimization step q = 4
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 312.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 211.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 164.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 36.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 220.0
#
# ###### Optimization step q = 5
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 233.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 479.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 264.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 196.0
#
# ###### Optimization step q = 6
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 128.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 588.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 503.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 300.0
#
# ###### Optimization step q = 7
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 126.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 164.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 672.0
#
# ###### Optimization step q = 12
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 152.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 399.0
#
# ###### Optimization step q = 8
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 160.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 254.0
#
# ###### Optimization step q = 13
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 222.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 650.0
#
# ###### Optimization step q = 9
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 80.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 102.0
#
# ###### Optimization step q = 14
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 250.0
#
# ###### Optimization step q = 12
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 318.0
#
# ###### Optimization step q = 10
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 37.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 54.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 276.0
#
# ###### Optimization step q = 13
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 150.0
#
# ###### Optimization step q = 11
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 494.0
#
# ###### Optimization step q = 14
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 94.0
#
# ###### Optimization step q = 12
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 656.0
#
# ###### Optimization step q = 15
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 55.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 257.0
#
# ###### Optimization step q = 16
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 124.0
#
# ###### Optimization step q = 17
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 94.0
#
# ###### Optimization step q = 18
# ################ Regime k = 0
# ################ Regime k = 1
#
# Optimal objective: reached.
# Difference in abs value between the previous and current gamma (shape num_regimesxT) : 57.0
# Iteration larger than 5 and two consecutive gammas are too similar. Go to next annealing.
#
# Done!

# %% [markdown]
# ## Plotting the results

# %%
T, N = data.shape

var_names = ['Rain', 'Nino34']

# %%
T, N
# Out:
# (1752, 2)

# %%
regimes = results['regimes'].argmax(axis=0)
n_regimes = len(results['causal_results'])



# Create nice Mosaic plot
mosaic = [['data %s' %j for i in range(n_regimes)] for j in range(N+1)]
for n in range(N):
    mosaic.append(['graph %s' %i for i in range(n_regimes)])

fig, axs = plt.subplot_mosaic(mosaic = mosaic, figsize=(20, 10))

for j in range(N):
    ax = axs['data %s' %j]
    ax.axhline(0., color='grey')
    ax.plot(datetime, data[:,j])
    for loc, spine in ax.spines.items():
        if loc != 'left':
            spine.set_color("none")
    
    ax.xaxis.set_ticks([])   
    ax.set_xlim(start_year, end_year+1)
    ax.set_ylabel(var_names[j])
    
# Regime variable
ax = axs['data %s' %N]
ax.plot(datetime, regimes.astype('int'), lw=3, color='black')
for loc, spine in ax.spines.items():
    if loc != 'left':
        spine.set_color("none")
ax.xaxis.set_ticks([]) 
ax.yaxis.set_ticks(range(n_regimes))   
ax.set_xlim(start_year, end_year+1)
ax.set_ylabel("Regime")
    
# Causal graphs for each regime
for w in range(n_regimes):
    if w == 0: show_colorbar=True
    else: show_colorbar = False
    tp.plot_graph(graph=results['causal_results'][w]['graph'], 
                  val_matrix=results['causal_results'][w]['val_matrix'], 
                  show_colorbar=show_colorbar,
                  var_names=var_names,
                  fig_ax=(fig, axs['graph %s' %w]))
    axs['graph %s' %w].set_title("Regime %d" %w, pad=-4)

fig.subplots_adjust(hspace=0.6)
plt.show()

# %%
results['causal_results'][0].keys()
# Out:
# dict_keys(['graph', 'p_matrix', 'val_matrix', 'conf_matrix'])

# %%
results['causal_results'][0]['val_matrix'][:,:,1]
# Out:
# array([[ 0.84565792,  0.05727553],
#        [-0.03244955,  0.43517453]])

# %%
results['causal_results'][0]['val_matrix'][:,:,2]
# Out:
# array([[ 0.23623933, -0.01032569],
#        [-0.01902909,  0.46897953]])

# %%
results['causal_results'][1]['val_matrix'][:,:,1]
# Out:
# array([[ 0.77848862,  0.00237011],
#        [-0.0291096 ,  0.77542738]])

# %%
results['causal_results'][1]['val_matrix'][:,:,2]
# Out:
# array([[-0.37677211, -0.0743581 ],
#        [-0.03834905, -0.10931544]])

# %% [markdown]
# ### Saving results

# %%
# save results to file
import pickle
import datetime
import os

now = datetime.datetime.now()
file_name = f"results_{now.strftime('%m-%d_%H-%M-%S')}.pkl"



with open(os.path.join('results', file_name), 'wb') as f:
    pickle.dump(results, f)

# %%
# load results from file
import os

file_name = "results_08-02_15-45-00.pkl"

with open(os.path.join('results', file_name), 'rb') as f:
    results = pickle.load(f)

# %% [markdown]
# ### Plotting seasonality of regimes

# %%
type(regimes)
# Out:
# numpy.ndarray

# %%
regime_groups = {'regime_1': {}, 'regime_2': {}}


for m in range(0, 12):

    month_regimes = regimes[m::12]
    regime_groups['regime_1'][m] = month_regimes[month_regimes == 0].shape[0]
    regime_groups['regime_2'][m] = month_regimes[month_regimes == 1].shape[0]

# plot regime groups
fig, ax = plt.subplots()

barWidth = 0.25

r1 = np.arange(len(regime_groups['regime_1']))
r2 = [x + barWidth for x in r1]

ax.bar(r1, regime_groups['regime_1'].values(), color='b', width=barWidth, edgecolor='grey', label='Regime 1')

ax.bar(r2, regime_groups['regime_2'].values(), color='r', width=barWidth, edgecolor='grey', label='Regime 2')

ax.set_xlabel('Months', fontweight='bold')

ax.set_ylabel('Number of months', fontweight='bold')

ax.set_xticks([r + barWidth for r in range(len(regime_groups['regime_1']))])

ax.set_xticklabels(regime_groups['regime_1'].keys())

ax.legend()

plt.show()
